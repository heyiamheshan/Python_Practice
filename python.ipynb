# %% [markdown]
# ## python tutorial

# %%
1+1

# %%
print("hello world")

# %%
type(1)

# %%
first_name='heshan'
last_name='pramuditha'

# %%
print("my first name is {} and last name is {}".format(first_name,last_name))
# Out:
# my first name is heshan and last name is pramuditha

# %%
type([1,2,4,5,67,])
# Out:
# list

# %%
str1="kasun"
str2="20"
str3="USA"
print("My name is {} , I  am {} years old ,I am living {} ".format(str1,int(str2),str3))
# Out:
# My name is kasun , I  am 20 years old ,I am living USA

# %%
my_str="hesh"

# %% [markdown]
# print(my_str.isalnum())

# %% [markdown]
# ## sets

# %%
set_var={"high","medium","low"}  #A set means unorderd collection data type 
print(set_var)
# Out:
# {'low', 'medium', 'high'}

# %%
#indexing 
set_var.add("extream high")

# %%
print(set_var)
# Out:
# {'extream high', 'low', 'medium', 'high'}

# %% [markdown]
# ## Dictonaries

# %%
my_dict={"car_type":"audi"}
print(my_dict)
# Out:
# {'car_type': 'audi'}

# %%
# we can add even for loop 
for x in my_dict:
    print(x)
# Out:
# car_type

# %% [markdown]
# ## Nested

# %%
car1_model={'Mercdes' : 1960}
car2_model={'audi':1970}
car3_model={'ambessador' : 1980}

car_type={'car1':car1_model, 'car2'}

# %% [markdown]
# ## Tuple

# %%
# not mutable 
my_tuple=("hesh","pramuditha")
print(my_tuple[0])
# Out:
# hesh

# %% [markdown]
# ## Numpy

# %%
  
import numpy as np 

my_list=[1,2,3,4,5,6]

arr=np.array(my_list)

# %%
print(arr)
# Out:
# [1 2 3 4 5 6]

# %%
arr.shape
# Out:
# (6,)

# %%
arr[0]
# Out:
# np.int64(1)

# %%
print(arr[0])
# Out:
# 1

# %%
# multinested array 
my_list1=[1,2,3,4,5,6]
my_list2=[3,5,6,8,5,8]
my_list3=[4,5,8,9,2,7]

# %%
arr=np.array([my_list1,my_list2,my_list3])

# %%
print(arr)
# Out:
# [[1 2 3 4 5 6]
#  [3 5 6 8 5 8]
#  [4 5 8 9 2 7]]

# %%
arr.shape
# Out:
# (3, 6)

# %%
arr.reshape(1,18)
# Out:
# array([[1, 2, 3, 4, 5, 6, 3, 5, 6, 8, 5, 8, 4, 5, 8, 9, 2, 7]])

# %%
# in 2 dimentional have 2 openening brackets , 1 dinemsional having one opnennig brackets 

# array opertaions are very fast

# %% [markdown]
# ## Indexing

# %%
import numpy as np
my_arr=([[1,2,3,4,5,6],[3,5,6,7,8,6]])


arr= np.array(my_arr)

# %%
print(arr)
# Out:
# [[1 2 3 4 5 6]
#  [3 5 6 7 8 6]]

# %%
arr[0:3]
# Out:
# array([[1, 2, 3, 4, 5, 6],
#        [3, 5, 6, 7, 8, 6]])

# %%
arr[:,:]
# Out:
# array([[1, 2, 3, 4, 5, 6],
#        [3, 5, 6, 7, 8, 6]])

# %%
my_arr3=([[[6,7,8],[8,9,0],[0,7,4]]])
arr3=np.array([my_arr3])

# %%
print(arr3)
# Out:
# [[[[6 7 8]
#    [8 9 0]
#    [0 7 4]]]]

# %%
arr3[1:2:1]
# Out:
# array([], shape=(0, 1, 3, 3), dtype=int64)

# %%
arr3[1:,1:]
# Out:
# array([], shape=(0, 0, 3, 3), dtype=int64)
